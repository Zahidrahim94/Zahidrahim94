# %% [markdown]
# # Python oprators

# %%
x=10
y=5

# %%
x+y
# Out:
# 15

# %%
x-y
# Out:
# 5

# %%
x*y
# Out:
# 50

# %%
x/y
# Out:
# 2.0

# %%
x**y
# Out:
# 100000

# %%
x//y
# Out:
# 2

# %%
x%y
# Out:
# 0

# %%
a=(1,2,3)
b=(3,2,1)
c=[1,2,3]
d=[3,2,1]
e={1,2,3}
f={3,2,1}

# %%
a+b
c+d
e+f
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-06b70e3088d2> in <module>
#       1 a+b
#       2 c+d
# ----> 3 e+f
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a-b
c-d
e-f
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-dd8650b251e5> in <module>
# ----> 1 a-b
#       2 c-d
#       3 e-f
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
a*b
c*d
e*f
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-8ce765dcfa30> in <module>
# ----> 1 a*b
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
a/b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-aae42d317509> in <module>
# ----> 1 a/b
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
a**b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-27166ff49cce> in <module>
# ----> 1 a**b
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'list'

# %%
a%b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-bd592a66b423> in <module>
# ----> 1 a%b
#
# TypeError: unsupported operand type(s) for %: 'list' and 'list'

# %%
a//b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-d84431c5cc8f> in <module>
# ----> 1 a//b
#
# TypeError: unsupported operand type(s) for //: 'list' and 'list'

# %% [markdown]
# # python assignment opretor

# %%
ab=5

# %%
ab
# Out:
# 5
