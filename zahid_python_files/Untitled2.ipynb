# %%
import math
import statistics
import numpy as np
import scipy as ab
c=[58,45,12,58,65,66,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,566,855,856,856,8,556,586,586,58,56,58,56,5,66,5,8,56,5,8,6,5,8,96,5,58,6,5,5896,5,5,6,85,6,8,8,5,9,9,9,8,8,9,9,8,9,8,9,999,8,999,9889,9,99,999,99,99,9,9,9,9,9]

def func():
# Arithmetic mean (“average”) of data.
    fmean()
# Fast, floating point arithmetic mean.
    geometric_mean()
# Geometric mean of data.
    harmonic_mean()
# Harmonic mean of data.
    median()
# Median (middle value) of data.
    median_low()
# Low median of data.
    median_high()
# High median of data.
    median_grouped()
# Median, or 50th percentile, of grouped data.
    mode()
# Single mode (most common value) of discrete or nominal data.
    multimode()
# List of modes (most common values) of discrete or nominal data.
    quantiles()
    # a=type("/home/autocanvas/Desktop/Zahid_AC_/app/AAI_SG/sg3d-00169-linux/Version.txt")
    # print(a)
    # e=sorted(c)
    # print(e)
    # t=sum(c)
    # print(t)

func()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-f3bcfb4f5581> in <module>
#       1 import math
# ----> 2 import statistics
#       3 import numpy as np
#       4 import scipy as ab
# ...

# %%
pip3 install  python-scipy python-numpy
# Out:
#   File "<ipython-input-7-c871a3972882>", line 1
#     pip3 install  python-scipy python-numpy
#                ^
# SyntaxError: invalid syntax
