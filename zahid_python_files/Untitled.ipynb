# %%
import array

# %%
a=array.array("i",[1,2,3,4,5,6,7])
b=array.array("i",["a","b","c","d","e","f","g"])

# %%
len(a)

# %%
a[2]

# %%
a[-2]

# %%
a

# %%
a.append(8)

# %%
a

# %%
a.extend([9,10,11,12])

# %%
a

# %%
a.insert(2,6)

# %%
a

# %%
a.pop()

# %%
a.pop(3)

# %%
a

# %%
a.pop(-1)

# %%
a.remove(10)

# %%
a

# %%
b=array.array("i",[16,17,18,19,20])

# %%
b

# %%
d=array.array("i")

# %%
d

# %%
d=a+b

# %%
d

# %%
d[0:5]

# %%
d[2:-4]

# %%
d

# %%
for x in d:
    print(x)

# %%
for x in d[0:3]:
    print(x)

# %%
d

# %%
temp=0
while temp<d[2]:
    print(d[temp])
    temp=temp+1

# %% [markdown]
# # hash table

# %%
my_dict={"dive":"001","ava":"002","joe":"003"}
print(my_dict)
type(my_dict)

# %%
new_dict=dict()
print(new_dict)

# %%
new_dict=dict(deve="001",ava="002")
print(new_dict)

# %% [markdown]
# # nested dictionaries

# %%
emp_details={"Employee":{"diioe":{"id":"001","salary":"2000","disignation":"team lead"},"ala":{"id":"002","salary":"3000","disignation":"team player"}}}
print(emp_details)

# %%
my_dict["ava"]

# %%
print(my_dict.keys())

# %%
print(my_dict.values())

# %%
for x in my_dict:
    print(x)

# %%
for x in my_dict.values():
    print(x)

# %%
for x,y in my_dict.items():
    print(x,y)

# %%
my_dict["dive"]="004"

# %%
my_dict

# %% [markdown]
# # dict to DF

# %%
import pandas as pd

# %% [markdown]
# # python operators

# %%
x=10

# %%
y=20

# %%
x+y

# %%
x-y

# %%
x*y

# %%
x**y

# %%
x/y

# %%
x//y

# %%
x%y

# %% [markdown]
# # assignment operator

# %%
x=100

# %%
x+=10

# %%
a

# %%
z=5

# %%
z+=5

# %%
z

# %%
z**=5

# %%
z

# %% [markdown]
# # comparison opreator

# %%
val=10

# %%
num=20

# %% [markdown]
# if val== num:
#     print("equa")

# %%
if val== num:
    print("equal")
elif val>num:
    print("grator")
else:
    print("smale")

# %%
10 & 12

# %%
10|12

# %%
10>>2

# %%
10<<2

# %%
101000<<2

# %%
101000>>2

# %%
a

# %%
for x in a:
    print(x)

# %%
for x in a[0:2]:
    print(x)

# %%
fc=0
while fc<a[2]:
    print(a[fc])
    fc=fc+1

# %%
u={"zahid":{"id":10,"positon":"dovelpoer","office":"islamabad"},"sadat":{"id":11,"positon":"devolper","office":"rawalpind"}}
print(u)

# %%
for x in u.items():
    print(x)

# %%
u["id"]=20
u["office"]="pesahwer"

# %%
u

# %%
u.pop("id")

# %%
u

# %%
j=10

# %%
k=50

# %%
j+k

# %%
j-y

# %%
j8k

# %%
j*k

# %%
j/y

# %%
j//k

# %%
x%y

# %%
j%y

# %%
j+=k

# %%
j

# %%
k

# %%
j**=5

# %%
j

# %%
h=2

# %%
h**=9

# %%
h

# %%
va=10

# %%
num23=20

# %%
campare=va<num23

# %%
campare

# %%
d=10

# %%
d

# %%
if va==num23:
    print(1)
elif va<num23:
    print(2)
else:
    print(3)

# %%
d>8 or d<6

# %%
d>8 and d>6

# %%
not(d<8 and d<6)

# %%
list=[10,20,30]

# %%
list1=[10,20,30]

# %%
list1

# %%
n=list

# %%
n

# %%
n is list

# %%
list is not list1

# %%
x in list1

# %%
list in list

# %%
10 in list1

# %%
"banan" is list

# %%
10&12

# %%
10|12

# %%
10>>2

# %%
10<<2

# %%
count=0
while count<9:
    print("number:", count)
    count=count+1
        
    
print("goddbay")

# %%
import random
n=20
to_be_guessed=int(n*random.random())
guess=0
while guess!=to_be_guessed:
    guess=int(input("new number: "))

# %%
import array

# %%
o=array.array("str",["a","b","b","d","e","f","g"])

# %%
print(o)
